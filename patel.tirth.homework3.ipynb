# %% [markdown]
# ## Problem 1
#
# ### ALOGRITHM:
#
# 1. Import the random module
# 2. Define a dictionary.
# 3. Take the user input for the name of the file and open it in the read mode.
# 4. Run a for loop to seperate the words in the sentences of the file by storing them in a variable 'word' and further store them in the dictionary.
# 5. Ask the user in order to start the program or to exit the program by asking to answer in the form of 'Yes' or 'No'.
# 6. following step 5 the key in the dictionary is scrambled with the help of a function defined called 'unsort'
# 7. The function 'mean' is iterated which asks the user to enter the answer or choose to know the meaning of the scarambled word by entering a character '?'
# 8. The user input is then checked for its validity and correctness, a seperate message is generated if the user guesses correctly and if the user guess the wrong word.
# 9. Lastly, the user is asked to either continue with the program or to exit the program by asking a 'yes' or 'no' input.
#
# ### CODE INSTRUCTIONS:
#
# * Start the program by selecting the cell
# * Program will stop after one iteration. To obtain different set of values, run thr program again.
# * Execute the cell containing function definition first and then the cell containing calling function after that.
#
# ### EXPECTED RESULT:
#
#     Give the name of the “words and their meanings” file: words.txt
#     Start the program by entering 'yes/Yes' or 'No/no': yes
#
#     Unscramble the following letters to form a word. Type “?” for the meaning of the unscrambled word:  neoymltgoo
#     Enter the answer [or ? for the meaning]: ?
#     The word means: study of insects
#     Enter the answer [or ? for the meaning]: entomology
#     You got it!
#     Do you want to continue [yes or no]: yes
#
#     Unscramble the following letters to form a word. Type “?” for the meaning of the unscrambled word:  ncuelope
#     Enter the answer [or ? for the meaning]: ?
#     The word means: great wealth
#     Enter the answer [or ? for the meaning]: opulence
#     You got it!
#     Do you want to continue [yes or no]: no
#
#     Goodbye!

# %%
#### unsort code #####
def unsort(key):                                                    #define a fn 'unsort'
    key1 = list(key)
    scramble = ""

    for letter in range(0, len(key1)):
        scramble += key1.pop(random.randint(0,len(key1)-1))        #scrambled the letters of word 
        
    return scramble

# %%
##### finding mean #####

def mean(key):                                                              #define a fn 'mean'
    while True:
        ans = input("Enter the answer [or ? for the meaning]: ")            #asked for an answer or to provide meaning 
        ans = ans.lower()
        if (ans =='?'):                          
            print("The word means:", dict[key])                             #showcased the meaning of the scrambled word
        elif (ans == key):
            print("You got it!")
            break
            
            if(user_input == 'yes'):                                        #Asked to either continue further or not
                continue
            elif(user_input == 'no'):
                break
            else:
                print("Enter a valid input!!")
        elif(ans != key):
            print("Wrong, try again")                               
        else:
            print("Enter a valid input!!")

# %%
##################################################### Code #################################################################

try:    
    import random

    dict={}

    file_name = input("Give the name of the “words and their meanings” file: ")   # enter filename   
    open_file = open(file_name,"r")                                               # read filename in read mode.
    
    for l in open_file:
            
        l = l.rstrip('\n')                                                        #strip the '\n' from the end of each line
        word=l.split(",", 1)                                                      #seperate the words through ','
        dict[word[0]] = ",".join(word[1:])

    useri = input ("Start the program by entering 'yes/Yes' or 'No/no': ")        #Asked whether to start the program 
    
    while True:  
        if (useri == 'yes') or (useri =='Yes'):    
            key = random.choice(list(dict))
            key = key.lower()
            scramble = unsort(key)                                                 #scramble the letters of the word
    
            print('\nUnscramble the following letters to form a word. Type “?” for the meaning of the unscrambled word: ', scramble)
    
            mean(key)                                                              #calling the function 'mean'
        
            useri = input("Do you want to continue [yes or no]: ")
        elif(useri == 'no') or (useri == 'No'):
            print("\nGoodbye!")
            break
        else:
            print("invalid input")
            useri = input ("Start the program by entering 'yes/Yes' or 'No/no' : ")
except:
    print("Enter valid file name!!")

# %% [markdown]
# ## Problem 2
#
# ### ALGORITHM:
#
# 1. Import numpy library.
# 2. Define a function called 'res' which tends to open the file in a read mode and splits the letter with ',' acting as a delimiter and stores the words in a dictionary.
# 3. define a function called 'cal' which is used to calculate the euclidean distance by taking the input from the user.
# 4. the function further compares the reviews of one reviewer with that of the other reviewers.
# 5. The try block asks rthe user to input the file name and inherits both the functions and runs them in accordance to requiremnets of the user.
# 6. The except block will handle the any exception regarding the file and thus pops out and error message.
#
# ### CODE INSTRUCTIONS:
#
# * Start the program by selecting the cell
# * Program will stop after one iteration. To obtain different set of values, run the program again.
# * There is a possibility that the program might terminate this happens due to the kernel so restart the kernel and run again.
#
# ### EXPECTED RESULT:
#
#     Give the name of the restaurant reviews file: restaurant_reviews.txt
#
#     What do you want to do? Input 1 for similarity between two reviewers, or Input 2 for similarity between one reviewer and all others in the database or 3 to quit:1
#
#     Provide Reviewer1 name: Jay Samuel
#     Provide Reviewer2 name: Corby Kumar
#     The similarity score is 1.5
#
#     What do you want to do? Input 1 for similarity between two reviewers, or Input 2 for similarity between one reviewer and all others in the database or 3 to quit:2
#
#     Provide Reviewer name: Corby Kumar
#
#     The similarity score are:
#     Corby Kumar      Tomm Sietsema      1.4142135623730951
#     Corby Kumar      Jonathan Golder      2.598076211353316
#     Corby Kumar      Brette Anderson      1.5811388300841898
#     Corby Kumar      Michael Baumer      2.179449471770337
#     Corby Kumar      Pete Wellsworth      2.5
#     Corby Kumar      Jay Samuel      1.5
#     Corby Kumar
#           0.0
#
#     What do you want to do? Input 1 for similarity between two reviewers, or Input 2 for similarity between one reviewer and all others in the database or 3 to quit:3
#
#     Goodbye

# %%
import numpy as np
dict = {}

def res(file):                                                      #function defination
    with open(file, "r") as f:
        for l in f:
            key, *values = l.split(",")                              #split the values with ',' as delimiter
            tmp = {}                                                 # nested dict by user
            i = iter(values)                                        #creating iterator from the list
            for k in i:
                 tmp[k] = float(next(i)) 
            dict[key] = tmp 
    return dict


def cal():                                                           #function to calculate the Euclidean distance
    useri = int(input("\nWhat do you want to do? Input 1 for similarity between two reviewers, or Input 2 for similarity between one reviewer and all others in the database or 3 to quit:"))
    if(useri == 1):
        n1 = input("\nProvide Reviewer1 name: ")                        #take first input from the user
        n2 = input("Provide Reviewer2 name: ")                        #take second input from the user
        sum1=0

        if n1 and n2 in nested_dict.keys():
            for i,iinfo in nested_dict.items():
                for j,jinfo in nested_dict.items():
                    if((i==n1) and j==n2):
                        for rest1 in iinfo:
                            for rest2 in jinfo:
                                if rest1==rest2:
                                    sum1=sum1+np.power((iinfo[rest1]-jinfo[rest2]),2)
                                #print(sum1)
            print('The similarity score is', np.sqrt(sum1))
        cal()

    elif(useri == 2):                                                 #condition for an input of value 2

        n1 = input("\nProvide Reviewer name: ")
        if n1 in nested_dict.keys():
            print("\nThe similarity score are:")
            for i,iinfo in nested_dict.items():
                
                for j,jinfo in nested_dict.items():
                    if(i==n1):
                        sum1=0
                        for rest1 in iinfo:
                            for rest2 in jinfo:
                                if rest1==rest2:
                                    sum1=sum1+np.power((iinfo[rest1]-jinfo[rest2]),2)
                            #print(sum1)
                        #print(j)
                       
                        if(n1!=j):
                            
                            print(n1 , "    " , j , "    " , np.sqrt(sum1))
                        #print('ans is', np.sqrt(sum1))
        cal()

    elif(useri == 3):                                                 ##condition for an input of value 3
        print("\nGoodbye!")

    else:
        print("Enter a valid input!!")
        cal()

    
try:                                                                              #try block
    filen = input("Give the name of the restaurant reviews file: ")           # enter filename    

    nested_dict=res(filen)
    run = cal()


except:                                                                           #except block
    print("Invalid input.")
