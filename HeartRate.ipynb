# %%
import random
import time
import datetime
 
#tm=datetime.datetime.now()

#f=open("HR_data.txt","a")


for i in range(2):
    print("No Heartbeat found!")
    time.sleep(.750)

    
for i in range(2):
    print("BPM :  71", end="")
    print("")
    time.sleep(.900)

    
for i in range(5):
    print ("BPM : " , random.randrange(68,73), end="")
    print("")
    #print ("BPM : ", end="")
    time.sleep(.900)


for i in range(4):
    print ("BPM : " , random.randrange(71,77), end="")
    print("")
    #print ("BPM : ", end="")
    time.sleep(.900)


for i in range(1):
    print("No Heartbeat found!")
    time.sleep(.750)


for i in range(8):
    print ("BPM : " , random.randrange(76,82), end="")
    print("")
    #print ("BPM : ", end="")
    time.sleep(.900)

    
for i in range(2):
    print("No Heartbeat found!")
    time.sleep(.750)

    
for i in range(15):
    print ("BPM : " , random.randrange(85,94,2), end="")
    print("")
    #print ("BPM : ", end="")
    time.sleep(.900)
# Out:
# No Heartbeat found!
# No Heartbeat found!
# BPM :  71
# BPM :  71
# BPM :  69
# BPM :  70
# BPM :  69
# BPM :  71
# BPM :  70
# BPM :  71
# BPM :  71
# BPM :  72
# BPM :  75
# No Heartbeat found!
# BPM :  79
# BPM :  80
# BPM :  79
# BPM :  81
# BPM :  79
# BPM :  78
# BPM :  78
# BPM :  79
# No Heartbeat found!
# No Heartbeat found!
# BPM :  93
# BPM :  85
# BPM :  87
# BPM :  89
# BPM :  85
# BPM :  91
# BPM :  87
# BPM :  91
# BPM :  93
# BPM :  87
# BPM :  87
# BPM :  93
# BPM :  91
# BPM :  87
# BPM :  89
